# %%
import keras
from matplotlib import pyplot as plt
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
digit=keras.datasets.mnist
(train_images,train_labels),(test_images, test_labels)=digit.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
plt.imshow(train_images[2])
print(train_labels[2])
# Out:
# 4

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
model=tf.keras.models.Sequential([tf.keras.layers.Flatten(), 
                                 tf.keras.layers.Dense(128,activation=tf.nn.relu),
                                 tf.keras.layers.Dense(10,activation=tf.nn.softmax)])

# %%
model.compile(optimizer=tf.train.AdamOptimizer(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=6)
# Out:
# Epoch 1/6
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.0353 - acc: 0.9891
# Epoch 2/6
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.0281 - acc: 0.9912
# Epoch 3/6
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.0225 - acc: 0.9927
# Epoch 4/6
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0197 - acc: 0.9939
# Epoch 5/6
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.0151 - acc: 0.9953
# Epoch 6/6
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.0124 - acc: 0.9963

# %%
acc=model.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 0s 40us/sample - loss: 0.0810 - acc: 0.9795

# %%
print(round(acc[1]*100))
# Out:
# 98.0
